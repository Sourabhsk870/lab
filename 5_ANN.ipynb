# %%
from math import exp
from random import seed
from random import random
 

def initialize_network(n_inputs, n_hidden, n_outputs):
    network = list()
    hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation

def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))
 

def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    return inputs
 

def transfer_derivative(output):
    return output * (1.0 - output)
 

def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])
 

def update_weights(network, row, l_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
                neuron['weights'][-1] += l_rate * neuron['delta']
 

def train_network(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
            print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
 

seed(1)

dataset = [[2.7810836,2.550537003,0],
    [1.465489372,2.362125076,0],
    [3.396561688,4.400293529,0],
    [1.38807019,1.850220317,0],
    [3.06407232,3.005305973,0],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]]
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
network = initialize_network(n_inputs, 2, n_outputs)
print(network)
train_network(network, dataset, 0.5, 20, n_outputs)
for layer in network:
    print(layer)
# Out:
# [[{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}, {'weights': [0.2550690257394217, 0.49543508709194095, 0.4494910647887381]}], [{'weights': [0.651592972722763, 0.7887233511355132, 0.0938595867742349]}, {'weights': [0.02834747652200631, 0.8357651039198697, 0.43276706790505337]}]]
# >epoch=0, lrate=0.500, error=0.634
# >epoch=0, lrate=0.500, error=1.187
# >epoch=0, lrate=0.500, error=1.671
# >epoch=0, lrate=0.500, error=2.054
# >epoch=0, lrate=0.500, error=2.369
# >epoch=0, lrate=0.500, error=3.365
# >epoch=0, lrate=0.500, error=4.243
# >epoch=0, lrate=0.500, error=5.015
# >epoch=0, lrate=0.500, error=5.653
# >epoch=0, lrate=0.500, error=6.226
# >epoch=1, lrate=0.500, error=0.637
# >epoch=1, lrate=0.500, error=1.159
# >epoch=1, lrate=0.500, error=1.586
# >epoch=1, lrate=0.500, error=1.925
# >epoch=1, lrate=0.500, error=2.197
# >epoch=1, lrate=0.500, error=3.129
# >epoch=1, lrate=0.500, error=3.900
# >epoch=1, lrate=0.500, error=4.524
# >epoch=1, lrate=0.500, error=4.984
# >epoch=1, lrate=0.500, error=5.397
# >epoch=2, lrate=0.500, error=0.726
# >epoch=2, lrate=0.500, error=1.308
# >epoch=2, lrate=0.500, error=1.769
# >epoch=2, lrate=0.500, error=2.139
# >epoch=2, lrate=0.500, error=2.429
# >epoch=2, lrate=0.500, error=3.294
# >epoch=2, lrate=0.500, error=3.987
# >epoch=2, lrate=0.500, error=4.528
# >epoch=2, lrate=0.500, error=4.897
# >epoch=2, lrate=0.500, error=5.269
# >epoch=3, lrate=0.500, error=0.747
# >epoch=3, lrate=0.500, error=1.345
# >epoch=3, lrate=0.500, error=1.815
# >epoch=3, lrate=0.500, error=2.197
# >epoch=3, lrate=0.500, error=2.497
# >epoch=3, lrate=0.500, error=3.311
# >epoch=3, lrate=0.500, error=3.948
# >epoch=3, lrate=0.500, error=4.404
# >epoch=3, lrate=0.500, error=4.734
# >epoch=3, lrate=0.500, error=5.068
# >epoch=4, lrate=0.500, error=0.719
# >epoch=4, lrate=0.500, error=1.280
# >epoch=4, lrate=0.500, error=1.720
# >epoch=4, lrate=0.500, error=2.086
# >epoch=4, lrate=0.500, error=2.379
# >epoch=4, lrate=0.500, error=3.076
# >epoch=4, lrate=0.500, error=3.622
# >epoch=4, lrate=0.500, error=4.020
# >epoch=4, lrate=0.500, error=4.348
# >epoch=4, lrate=0.500, error=4.638
# >epoch=5, lrate=0.500, error=0.673
# >epoch=5, lrate=0.500, error=1.161
# >epoch=5, lrate=0.500, error=1.543
# >epoch=5, lrate=0.500, error=1.866
# >epoch=5, lrate=0.500, error=2.132
# >epoch=5, lrate=0.500, error=2.761
# >epoch=5, lrate=0.500, error=3.285
# >epoch=5, lrate=0.500, error=3.670
# >epoch=5, lrate=0.500, error=3.989
# >epoch=5, lrate=0.500, error=4.268
# >epoch=6, lrate=0.500, error=0.628
# >epoch=6, lrate=0.500, error=1.049
# >epoch=6, lrate=0.500, error=1.376
# >epoch=6, lrate=0.500, error=1.660
# >epoch=6, lrate=0.500, error=1.898
# >epoch=6, lrate=0.500, error=2.485
# >epoch=6, lrate=0.500, error=2.985
# >epoch=6, lrate=0.500, error=3.344
# >epoch=6, lrate=0.500, error=3.642
# >epoch=6, lrate=0.500, error=3.904
# >epoch=7, lrate=0.500, error=0.587
# >epoch=7, lrate=0.500, error=0.953
# >epoch=7, lrate=0.500, error=1.236
# >epoch=7, lrate=0.500, error=1.489
# >epoch=7, lrate=0.500, error=1.705
# >epoch=7, lrate=0.500, error=2.243
# >epoch=7, lrate=0.500, error=2.710
# >epoch=7, lrate=0.500, error=3.036
# >epoch=7, lrate=0.500, error=3.308
# >epoch=7, lrate=0.500, error=3.549
# >epoch=8, lrate=0.500, error=0.548
# >epoch=8, lrate=0.500, error=0.866
# >epoch=8, lrate=0.500, error=1.115
# >epoch=8, lrate=0.500, error=1.342
# >epoch=8, lrate=0.500, error=1.538
# >epoch=8, lrate=0.500, error=2.023
# >epoch=8, lrate=0.500, error=2.455
# >epoch=8, lrate=0.500, error=2.748
# >epoch=8, lrate=0.500, error=2.994
# >epoch=8, lrate=0.500, error=3.214
# >epoch=9, lrate=0.500, error=0.506
# >epoch=9, lrate=0.500, error=0.784
# >epoch=9, lrate=0.500, error=1.004
# >epoch=9, lrate=0.500, error=1.209
# >epoch=9, lrate=0.500, error=1.389
# >epoch=9, lrate=0.500, error=1.820
# >epoch=9, lrate=0.500, error=2.218
# >epoch=9, lrate=0.500, error=2.480
# >epoch=9, lrate=0.500, error=2.701
# >epoch=9, lrate=0.500, error=2.901
# >epoch=10, lrate=0.500, error=0.463
# >epoch=10, lrate=0.500, error=0.707
# >epoch=10, lrate=0.500, error=0.903
# >epoch=10, lrate=0.500, error=1.087
# >epoch=10, lrate=0.500, error=1.253
# >epoch=10, lrate=0.500, error=1.633
# >epoch=10, lrate=0.500, error=1.999
# >epoch=10, lrate=0.500, error=2.234
# >epoch=10, lrate=0.500, error=2.432
# >epoch=10, lrate=0.500, error=2.615
# >epoch=11, lrate=0.500, error=0.420
# >epoch=11, lrate=0.500, error=0.634
# >epoch=11, lrate=0.500, error=0.810
# >epoch=11, lrate=0.500, error=0.977
# >epoch=11, lrate=0.500, error=1.129
# >epoch=11, lrate=0.500, error=1.464
# >epoch=11, lrate=0.500, error=1.801
# >epoch=11, lrate=0.500, error=2.010
# >epoch=11, lrate=0.500, error=2.189
# >epoch=11, lrate=0.500, error=2.356
# >epoch=12, lrate=0.500, error=0.379
# >epoch=12, lrate=0.500, error=0.568
# >epoch=12, lrate=0.500, error=0.726
# >epoch=12, lrate=0.500, error=0.877
# >epoch=12, lrate=0.500, error=1.018
# >epoch=12, lrate=0.500, error=1.312
# >epoch=12, lrate=0.500, error=1.621
# >epoch=12, lrate=0.500, error=1.810
# >epoch=12, lrate=0.500, error=1.971
# >epoch=12, lrate=0.500, error=2.124
# >epoch=13, lrate=0.500, error=0.340
# >epoch=13, lrate=0.500, error=0.507
# >epoch=13, lrate=0.500, error=0.651
# >epoch=13, lrate=0.500, error=0.788
# >epoch=13, lrate=0.500, error=0.919
# >epoch=13, lrate=0.500, error=1.177
# >epoch=13, lrate=0.500, error=1.461
# >epoch=13, lrate=0.500, error=1.631
# >epoch=13, lrate=0.500, error=1.776
# >epoch=13, lrate=0.500, error=1.917
# >epoch=14, lrate=0.500, error=0.304
# >epoch=14, lrate=0.500, error=0.454
# >epoch=14, lrate=0.500, error=0.584
# >epoch=14, lrate=0.500, error=0.709
# >epoch=14, lrate=0.500, error=0.830
# >epoch=14, lrate=0.500, error=1.058
# >epoch=14, lrate=0.500, error=1.318
# >epoch=14, lrate=0.500, error=1.472
# >epoch=14, lrate=0.500, error=1.604
# >epoch=14, lrate=0.500, error=1.733
# >epoch=15, lrate=0.500, error=0.272
# >epoch=15, lrate=0.500, error=0.406
# >epoch=15, lrate=0.500, error=0.524
# >epoch=15, lrate=0.500, error=0.639
# >epoch=15, lrate=0.500, error=0.752
# >epoch=15, lrate=0.500, error=0.954
# >epoch=15, lrate=0.500, error=1.191
# >epoch=15, lrate=0.500, error=1.331
# >epoch=15, lrate=0.500, error=1.451
# >epoch=15, lrate=0.500, error=1.571
# >epoch=16, lrate=0.500, error=0.244
# >epoch=16, lrate=0.500, error=0.364
# >epoch=16, lrate=0.500, error=0.472
# >epoch=16, lrate=0.500, error=0.577
# >epoch=16, lrate=0.500, error=0.682
# >epoch=16, lrate=0.500, error=0.862
# >epoch=16, lrate=0.500, error=1.079
# >epoch=16, lrate=0.500, error=1.206
# >epoch=16, lrate=0.500, error=1.316
# >epoch=16, lrate=0.500, error=1.427
# >epoch=17, lrate=0.500, error=0.220
# >epoch=17, lrate=0.500, error=0.327
# >epoch=17, lrate=0.500, error=0.426
# >epoch=17, lrate=0.500, error=0.522
# >epoch=17, lrate=0.500, error=0.620
# >epoch=17, lrate=0.500, error=0.781
# >epoch=17, lrate=0.500, error=0.980
# >epoch=17, lrate=0.500, error=1.096
# >epoch=17, lrate=0.500, error=1.196
# >epoch=17, lrate=0.500, error=1.299
# >epoch=18, lrate=0.500, error=0.198
# >epoch=18, lrate=0.500, error=0.295
# >epoch=18, lrate=0.500, error=0.385
# >epoch=18, lrate=0.500, error=0.474
# >epoch=18, lrate=0.500, error=0.565
# >epoch=18, lrate=0.500, error=0.710
# >epoch=18, lrate=0.500, error=0.892
# >epoch=18, lrate=0.500, error=0.998
# >epoch=18, lrate=0.500, error=1.090
# >epoch=18, lrate=0.500, error=1.186
# >epoch=19, lrate=0.500, error=0.179
# >epoch=19, lrate=0.500, error=0.267
# >epoch=19, lrate=0.500, error=0.349
# >epoch=19, lrate=0.500, error=0.431
# >epoch=19, lrate=0.500, error=0.516
# >epoch=19, lrate=0.500, error=0.647
# >epoch=19, lrate=0.500, error=0.814
# >epoch=19, lrate=0.500, error=0.912
# >epoch=19, lrate=0.500, error=0.996
# >epoch=19, lrate=0.500, error=1.085
# [{'weights': [-1.4991574097533398, 1.8124462072040899, 1.373562784124192], 'output': 0.02661557520048483, 'delta': -0.004706282904724357}, {'weights': [0.38909594876157794, -0.09039690106810404, 0.09004471193724925], 'output': 0.9349011172710473, 'delta': 0.0025732266804154367}]
# [{'weights': [2.6333219309236275, -0.1497531360187956, -1.2649549004379637], 'output': 0.2172490655284883, 'delta': -0.03694361833364}, {'weights': [-2.5156632435951014, 1.1307827752337396, 0.4107875725651124], 'output': 0.7945888880040852, 'delta': 0.03352666497398998}]
